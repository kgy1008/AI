# %% [markdown]
# <a href="https://colab.research.google.com/github/kgy1008/Yolov7/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %%
# !pip install -U portalocker>=2.0.0

# %%
import torch
from torchtext.datasets import AG_NEWS

train_iter = iter(AG_NEWS(split="train"))

# %%
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

tokenizer = get_tokenizer("basic_english")
train_iter = AG_NEWS(split="train")


def yield_tokens(data_iter):
    for _, text in data_iter:
        yield tokenizer(text)


vocab = build_vocab_from_iterator(yield_tokens(train_iter), specials=["<unk>"])
vocab.set_default_index(vocab["<unk>"])

# %%
text_pipeline = lambda x: vocab(tokenizer(x))
label_pipeline = lambda x: int(x) - 1

# %%
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


def collate_batch(batch):
    label_list, text_list, offsets = [], [], [0]
    for _label, _text in batch:
        label_list.append(label_pipeline(_label))
        processed_text = torch.tensor(text_pipeline(_text), dtype=torch.int64)
        text_list.append(processed_text)
        offsets.append(processed_text.size(0))
    label_list = torch.tensor(label_list, dtype=torch.int64)
    offsets = torch.tensor(offsets[:-1]).cumsum(dim=0)
    text_list = torch.cat(text_list)
    return label_list.to(device), text_list.to(device), offsets.to(device)


train_iter = AG_NEWS(split="train")
dataloader = DataLoader(
    train_iter, batch_size=8, shuffle=False, collate_fn=collate_batch
)

# %%
from torch import nn


class TextClassificationModel(nn.Module):
    def __init__(self, vocab_size, embed_dim, num_class):
        super(TextClassificationModel, self).__init__()
        self.embedding = nn.EmbeddingBag(vocab_size, embed_dim, sparse=False)
        self.fc = nn.Linear(embed_dim, num_class)
        self.init_weights()

    def init_weights(self):
        initrange = 0.5
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.fc.weight.data.uniform_(-initrange, initrange)
        self.fc.bias.data.zero_()

    def forward(self, text, offsets):
        """
        Here, you can modify the code to add layers.
        """
        embedded = self.embedding(text, offsets)
        output = self.fc(embedded)
        return output

# %%
train_iter = AG_NEWS(split="train")
num_class = len(set([label for (label, text) in train_iter]))
vocab_size = len(vocab)
emsize = 64 # Here, you can modify the code to change the embedding size.
model = TextClassificationModel(vocab_size, emsize, num_class).to(device)

# %%
import time


def train(dataloader):
    model.train()
    total_acc, total_count = 0, 0
    log_interval = 500
    start_time = time.time()

    for idx, (label, text, offsets) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_label = model(text, offsets)
        loss = criterion(predicted_label, label)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predicted_label.argmax(1) == label).sum().item()
        total_count += label.size(0)
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            print(
                "| epoch {:3d} | {:5d}/{:5d} batches "
                "| accuracy {:8.3f}".format(
                    epoch, idx, len(dataloader), total_acc / total_count
                )
            )
            total_acc, total_count = 0, 0
            start_time = time.time()


def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0

    with torch.no_grad():
        for idx, (label, text, offsets) in enumerate(dataloader):
            predicted_label = model(text, offsets)
            loss = criterion(predicted_label, label)
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
    return total_acc / total_count

# %%
from torch.utils.data.dataset import random_split
from torchtext.data.functional import to_map_style_dataset

# Hyperparameters
EPOCHS = 50  # epoch # Here, you can modify the code to change the value of epoch.
LR = 0.01  # learning rate
BATCH_SIZE = 64  # batch size for training

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=LR) # Here, you can modify the code to change the optimizer.
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.1)
total_accu = None
train_iter, test_iter = AG_NEWS()
train_dataset = to_map_style_dataset(train_iter)
test_dataset = to_map_style_dataset(test_iter)
num_train = int(len(train_dataset) * 0.95)
split_train_, split_valid_ = random_split(
    train_dataset, [num_train, len(train_dataset) - num_train]
)

train_dataloader = DataLoader(
    split_train_, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_batch
)
valid_dataloader = DataLoader(
    split_valid_, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_batch
)
test_dataloader = DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_batch
)

for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train(train_dataloader)
    accu_val = evaluate(valid_dataloader)
    if total_accu is not None and total_accu > accu_val:
        scheduler.step()
    else:
        total_accu = accu_val
    print("-" * 59)
    print(
        "| end of epoch {:3d} | time: {:5.2f}s | "
        "valid accuracy {:8.3f} ".format(
            epoch, time.time() - epoch_start_time, accu_val
        )
    )
    print("-" * 59)
# Out:
# | epoch   1 |   500/ 1782 batches | accuracy    0.968
# | epoch   1 |  1000/ 1782 batches | accuracy    0.968
# | epoch   1 |  1500/ 1782 batches | accuracy    0.964
# -----------------------------------------------------------
# | end of epoch   1 | time: 10.70s | valid accuracy    0.962
# -----------------------------------------------------------
# | epoch   2 |   500/ 1782 batches | accuracy    0.972
# | epoch   2 |  1000/ 1782 batches | accuracy    0.970
# | epoch   2 |  1500/ 1782 batches | accuracy    0.967
# -----------------------------------------------------------
# | end of epoch   2 | time: 11.05s | valid accuracy    0.956
# -----------------------------------------------------------
# | epoch   3 |   500/ 1782 batches | accuracy    0.976
# | epoch   3 |  1000/ 1782 batches | accuracy    0.977
# | epoch   3 |  1500/ 1782 batches | accuracy    0.977
# -----------------------------------------------------------
# | end of epoch   3 | time: 11.01s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch   4 |   500/ 1782 batches | accuracy    0.977
# | epoch   4 |  1000/ 1782 batches | accuracy    0.979
# | epoch   4 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch   4 | time: 11.11s | valid accuracy    0.957
# -----------------------------------------------------------
# | epoch   5 |   500/ 1782 batches | accuracy    0.978
# | epoch   5 |  1000/ 1782 batches | accuracy    0.979
# | epoch   5 |  1500/ 1782 batches | accuracy    0.977
# -----------------------------------------------------------
# | end of epoch   5 | time: 11.15s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch   6 |   500/ 1782 batches | accuracy    0.977
# | epoch   6 |  1000/ 1782 batches | accuracy    0.978
# | epoch   6 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch   6 | time: 11.12s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch   7 |   500/ 1782 batches | accuracy    0.978
# | epoch   7 |  1000/ 1782 batches | accuracy    0.979
# | epoch   7 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch   7 | time: 11.09s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch   8 |   500/ 1782 batches | accuracy    0.979
# | epoch   8 |  1000/ 1782 batches | accuracy    0.977
# | epoch   8 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch   8 | time: 11.05s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch   9 |   500/ 1782 batches | accuracy    0.978
# | epoch   9 |  1000/ 1782 batches | accuracy    0.979
# | epoch   9 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch   9 | time: 11.19s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  10 |   500/ 1782 batches | accuracy    0.979
# | epoch  10 |  1000/ 1782 batches | accuracy    0.979
# | epoch  10 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  10 | time: 11.19s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  11 |   500/ 1782 batches | accuracy    0.976
# | epoch  11 |  1000/ 1782 batches | accuracy    0.978
# | epoch  11 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  11 | time: 10.98s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  12 |   500/ 1782 batches | accuracy    0.977
# | epoch  12 |  1000/ 1782 batches | accuracy    0.978
# | epoch  12 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  12 | time: 10.80s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  13 |   500/ 1782 batches | accuracy    0.978
# | epoch  13 |  1000/ 1782 batches | accuracy    0.979
# | epoch  13 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  13 | time: 11.12s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  14 |   500/ 1782 batches | accuracy    0.978
# | epoch  14 |  1000/ 1782 batches | accuracy    0.979
# | epoch  14 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  14 | time: 11.12s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  15 |   500/ 1782 batches | accuracy    0.977
# | epoch  15 |  1000/ 1782 batches | accuracy    0.979
# | epoch  15 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  15 | time: 11.23s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  16 |   500/ 1782 batches | accuracy    0.978
# | epoch  16 |  1000/ 1782 batches | accuracy    0.978
# | epoch  16 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  16 | time: 11.20s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  17 |   500/ 1782 batches | accuracy    0.979
# | epoch  17 |  1000/ 1782 batches | accuracy    0.978
# | epoch  17 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  17 | time: 11.14s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  18 |   500/ 1782 batches | accuracy    0.978
# | epoch  18 |  1000/ 1782 batches | accuracy    0.979
# | epoch  18 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  18 | time: 11.88s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  19 |   500/ 1782 batches | accuracy    0.977
# | epoch  19 |  1000/ 1782 batches | accuracy    0.978
# | epoch  19 |  1500/ 1782 batches | accuracy    0.980
# -----------------------------------------------------------
# | end of epoch  19 | time: 11.19s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  20 |   500/ 1782 batches | accuracy    0.978
# | epoch  20 |  1000/ 1782 batches | accuracy    0.979
# | epoch  20 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  20 | time: 11.36s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  21 |   500/ 1782 batches | accuracy    0.977
# | epoch  21 |  1000/ 1782 batches | accuracy    0.979
# | epoch  21 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  21 | time: 11.16s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  22 |   500/ 1782 batches | accuracy    0.978
# | epoch  22 |  1000/ 1782 batches | accuracy    0.977
# | epoch  22 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  22 | time: 11.23s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  23 |   500/ 1782 batches | accuracy    0.977
# | epoch  23 |  1000/ 1782 batches | accuracy    0.978
# | epoch  23 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  23 | time: 11.25s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  24 |   500/ 1782 batches | accuracy    0.978
# | epoch  24 |  1000/ 1782 batches | accuracy    0.978
# | epoch  24 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  24 | time: 10.77s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  25 |   500/ 1782 batches | accuracy    0.977
# | epoch  25 |  1000/ 1782 batches | accuracy    0.979
# | epoch  25 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  25 | time: 10.99s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  26 |   500/ 1782 batches | accuracy    0.978
# | epoch  26 |  1000/ 1782 batches | accuracy    0.978
# | epoch  26 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  26 | time: 11.84s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  27 |   500/ 1782 batches | accuracy    0.977
# | epoch  27 |  1000/ 1782 batches | accuracy    0.980
# | epoch  27 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  27 | time: 11.23s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  28 |   500/ 1782 batches | accuracy    0.978
# | epoch  28 |  1000/ 1782 batches | accuracy    0.977
# | epoch  28 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  28 | time: 11.22s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  29 |   500/ 1782 batches | accuracy    0.979
# | epoch  29 |  1000/ 1782 batches | accuracy    0.977
# | epoch  29 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  29 | time: 11.11s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  30 |   500/ 1782 batches | accuracy    0.978
# | epoch  30 |  1000/ 1782 batches | accuracy    0.977
# | epoch  30 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  30 | time: 11.38s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  31 |   500/ 1782 batches | accuracy    0.978
# | epoch  31 |  1000/ 1782 batches | accuracy    0.977
# | epoch  31 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  31 | time: 11.42s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  32 |   500/ 1782 batches | accuracy    0.977
# | epoch  32 |  1000/ 1782 batches | accuracy    0.979
# | epoch  32 |  1500/ 1782 batches | accuracy    0.977
# -----------------------------------------------------------
# | end of epoch  32 | time: 11.30s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  33 |   500/ 1782 batches | accuracy    0.980
# | epoch  33 |  1000/ 1782 batches | accuracy    0.979
# | epoch  33 |  1500/ 1782 batches | accuracy    0.976
# -----------------------------------------------------------
# | end of epoch  33 | time: 11.30s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  34 |   500/ 1782 batches | accuracy    0.978
# | epoch  34 |  1000/ 1782 batches | accuracy    0.977
# | epoch  34 |  1500/ 1782 batches | accuracy    0.980
# -----------------------------------------------------------
# | end of epoch  34 | time: 11.28s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  35 |   500/ 1782 batches | accuracy    0.978
# | epoch  35 |  1000/ 1782 batches | accuracy    0.978
# | epoch  35 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  35 | time: 11.16s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  36 |   500/ 1782 batches | accuracy    0.979
# | epoch  36 |  1000/ 1782 batches | accuracy    0.978
# | epoch  36 |  1500/ 1782 batches | accuracy    0.977
# -----------------------------------------------------------
# | end of epoch  36 | time: 10.81s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  37 |   500/ 1782 batches | accuracy    0.977
# | epoch  37 |  1000/ 1782 batches | accuracy    0.978
# | epoch  37 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  37 | time: 10.82s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  38 |   500/ 1782 batches | accuracy    0.977
# | epoch  38 |  1000/ 1782 batches | accuracy    0.979
# | epoch  38 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  38 | time: 11.05s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  39 |   500/ 1782 batches | accuracy    0.979
# | epoch  39 |  1000/ 1782 batches | accuracy    0.978
# | epoch  39 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  39 | time: 11.05s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  40 |   500/ 1782 batches | accuracy    0.979
# | epoch  40 |  1000/ 1782 batches | accuracy    0.978
# | epoch  40 |  1500/ 1782 batches | accuracy    0.977
# -----------------------------------------------------------
# | end of epoch  40 | time: 11.02s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  41 |   500/ 1782 batches | accuracy    0.979
# | epoch  41 |  1000/ 1782 batches | accuracy    0.977
# | epoch  41 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  41 | time: 11.15s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  42 |   500/ 1782 batches | accuracy    0.978
# | epoch  42 |  1000/ 1782 batches | accuracy    0.978
# | epoch  42 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  42 | time: 11.22s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  43 |   500/ 1782 batches | accuracy    0.979
# | epoch  43 |  1000/ 1782 batches | accuracy    0.979
# | epoch  43 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  43 | time: 11.22s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  44 |   500/ 1782 batches | accuracy    0.979
# | epoch  44 |  1000/ 1782 batches | accuracy    0.978
# | epoch  44 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  44 | time: 11.31s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  45 |   500/ 1782 batches | accuracy    0.977
# | epoch  45 |  1000/ 1782 batches | accuracy    0.979
# | epoch  45 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  45 | time: 11.14s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  46 |   500/ 1782 batches | accuracy    0.979
# | epoch  46 |  1000/ 1782 batches | accuracy    0.978
# | epoch  46 |  1500/ 1782 batches | accuracy    0.977
# -----------------------------------------------------------
# | end of epoch  46 | time: 11.17s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  47 |   500/ 1782 batches | accuracy    0.979
# | epoch  47 |  1000/ 1782 batches | accuracy    0.978
# | epoch  47 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  47 | time: 11.37s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  48 |   500/ 1782 batches | accuracy    0.978
# | epoch  48 |  1000/ 1782 batches | accuracy    0.979
# | epoch  48 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  48 | time: 10.76s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  49 |   500/ 1782 batches | accuracy    0.979
# | epoch  49 |  1000/ 1782 batches | accuracy    0.978
# | epoch  49 |  1500/ 1782 batches | accuracy    0.978
# -----------------------------------------------------------
# | end of epoch  49 | time: 10.96s | valid accuracy    0.958
# -----------------------------------------------------------
# | epoch  50 |   500/ 1782 batches | accuracy    0.978
# | epoch  50 |  1000/ 1782 batches | accuracy    0.977
# | epoch  50 |  1500/ 1782 batches | accuracy    0.979
# -----------------------------------------------------------
# | end of epoch  50 | time: 11.11s | valid accuracy    0.958
# -----------------------------------------------------------

# %%
print("Checking the results of test dataset.")
accu_test = evaluate(test_dataloader)
print("test accuracy {:8.3f}".format(accu_test))
# Out:
# Checking the results of test dataset.
# test accuracy    0.912

# %%
ag_news_label = {1: "World", 2: "Sports", 3: "Business", 4: "Sci/Tec"}


def predict(text, text_pipeline):
    with torch.no_grad():
        text = torch.tensor(text_pipeline(text))
        output = model(text, torch.tensor([0]))
        return output.argmax(1).item() + 1


ex_text_str = "MEMPHIS, Tenn. – Four days ago, Jon Rahm was \
    enduring the season’s worst weather conditions on Sunday at The \
    Open on his way to a closing 75 at Royal Portrush, which \
    considering the wind and the rain was a respectable showing. \
    Thursday’s first round at the WGC-FedEx St. Jude Invitational \
    was another story. With temperatures in the mid-80s and hardly any \
    wind, the Spaniard was 13 strokes better in a flawless round. \
    Thanks to his best putting performance on the PGA Tour, Rahm \
    finished with an 8-under 62 for a three-stroke lead, which \
    was even more impressive considering he’d never played the \
    front nine at TPC Southwind."

model = model.to("cpu")

print("This is a %s news" % ag_news_label[predict(ex_text_str, text_pipeline)])
